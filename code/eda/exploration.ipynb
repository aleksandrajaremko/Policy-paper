# %%
# %load_ext IPython.extensions.autoreload
# %reload_ext IPython.extensions.autoreload

# %%
import numpy as np
import pandas as pd

import openpyxl

import sys
import os
import runpy

import requests
from io import StringIO
import json

import json
import glob
from pathlib import Path

# %%
os.chdir('../..')
os.getcwd()
# Out:
# 'c:\\Users\\jarem\\OneDrive - London School of Economics\\YEAR 2\\PP4V8 - policy paper\\policy-paper-repo'

# %% [markdown]
# # Operationalisation of variables

# %% [markdown]
# ## 1. Eligible regions (NUTS)

# %%
nuts_eligible_14_20 = pd.read_excel(r"data\inputs\cohesion_data_europa\Cohesion_policy_indicators_2024.xlsx", sheet_name="M3")
nuts_eligible_14_20 = nuts_eligible_14_20[["NUTS", "VALUE"]]

# %%
iso3_eligible_14_20 = pd.read_excel(r"data\inputs\cohesion_data_europa\Cohesion_policy_indicators_2024.xlsx", sheet_name="M4")
iso3_eligible_14_20 = iso3_eligible_14_20[["NUTS", "VALUE"]]

# %%
nuts_eligible_21_27 = pd.read_excel(r"data\inputs\cohesion_data_europa\Cohesion_policy_indicators_2024.xlsx", sheet_name="M1")
nuts_eligible_21_27 = nuts_eligible_21_27[["NUTS", "VALUE"]]

# %%
iso3_eligible_21_27 = pd.read_excel(r"data\inputs\cohesion_data_europa\Cohesion_policy_indicators_2024.xlsx", sheet_name="M2")
iso3_eligible_21_27 = iso3_eligible_21_27[["NUTS", "VALUE"]]

# %%
nuts_eligibility_dict = {
    1 : "Less developed regions" , 
    2 : "Transition regions", 
    3 : "More developed regions"   
}

iso3_eligibility_dict = {
    1 : "Suppoerted" , 
    2 : "Supported on a transitional and specific basis", 
    3 : "Not supported"   
}

# %%
# sum(nuts_eligible_21_27.VALUE == 2 )

# %% [markdown]
# ## Dane GUS

# %% [markdown]
# ### Programme period: 2014 - 2020

# %%
PL_projects_14_20= pd.read_excel(r"data\inputs\dane_gus\lista_projektow_UE_2014_20\Lista_projektow_FE_2014_2020_02112025.xlsx", header = 2)

# %% [markdown]
# #### Clean up data

# %%
from src.functions import *

# %%
PL_projects_14_20.drop(columns=[
    "Forma finansowania/ Form of finance",
    "Projekt realizowany w ramach terytorialnych mechanizmów wdrażania/ Project implemented under territorial delivery mechanisms",
    "Działanie/ Measure",
    "Poddziałanie/ Submeasure",
    "Dziedzina działalności gospodarczej, której dotyczy projekt/ Area of economic activity",
    "Obszar wsparcia projektu/ Area of project intervention",
    "Cel projektu/ Project thematic objective",
    "Cel uzupełniający dla projektów EFS/ ESF secondary theme"
], inplace=True)
PL_projects_14_20 = clean_english_colnames(PL_projects_14_20, normalize='keep')   
PL_projects_14_20 = PL_projects_14_20[PL_projects_14_20['Fund'] != 'BAR']

# %%
PL_projects_14_20['Amount of EU co-financing (EUR)'] = PL_projects_14_20['Amount of EU co-financing (PLN, for ETC projects EUR)']/4.4975 # this exchange rate was taken from the report

# %%
# PL_projects_14_20.columns

# %%
df_locations = unnest_locations(PL_projects_14_20, 'Project location', 'Amount of EU co-financing (PLN, for ETC projects EUR)','Amount of EU co-financing (EUR)')

print(f"Original rows: {len(PL_projects_14_20)}")
print(f"Rows after unnesting: {len(df_locations)}")
# Out:
# Original rows: 103189
# Rows after unnesting: 143327

# %%
# add country marker
df_locations = add_iso3_column(df_locations)

# %%
# display(df_locations[['Contract number','Project location', 'woj', 'pow', 'funding_split']].head(10))
# display(df_locations.head(3))

# %%
# save output
df_locations.to_csv(r"data\outputs\eu_flows\pol_1420_projects_by_location.csv", index=False)

# %%
# df_locations["Project location"].unique().tolist()

# %% [markdown]
# #### Reshape df so that powiats are row indexes
#
# panel structure with treatment timing

# %%
df_locations = df_locations[df_locations['iso3'] == 'POL']

# %%
# Convert dates to datetime
df_locations['Project start date'] = pd.to_datetime(df_locations['Project start date'], errors='coerce')
df_locations['Project end date'] = pd.to_datetime(df_locations['Project end date'], errors='coerce')

# Extract year of first project (treatment year)
df_locations['year_start'] = df_locations['Project start date'].dt.year

# Create treatment variable: year when powiat first received EU funding
df_treatment_timing = df_locations.groupby('pow').agg({
    'year_start': 'min',  # first year treated
    'funding_split': 'sum',
    'Contract number': 'nunique'
}).reset_index()
df_treatment_timing.columns = ['pow', 'treatment_year', 'total_funding', 'num_projects']

# Create binary treatment indicator for each year
# For staggered DiD: treated = 1 if year >= treatment_year for that powiat
years = range(df_locations['year_start'].min(), df_locations['year_start'].max() + 1)
treatment_data = []

for pow in df_treatment_timing['pow'].unique():
    treat_year = df_treatment_timing[df_treatment_timing['pow'] == pow]['treatment_year'].values[0]
    for year in years:
        treatment_data.append({
            'pow': pow,
            'year': year,
            'treated': 1 if year >= treat_year else 0,
            'time_to_treatment': year - treat_year if year >= treat_year else None
        })

df_staggered_did = pd.DataFrame(treatment_data)

# Add cumulative funding received by that year (for intensity)
df_funding_by_year = df_locations.groupby(['pow', 'year_start'])['funding_split'].sum().reset_index()
df_funding_by_year.columns = ['pow', 'year', 'funding_that_year']
df_funding_by_year['funding_cum'] = df_funding_by_year.groupby('pow')['funding_that_year'].cumsum()

df_staggered_did = df_staggered_did.merge(df_funding_by_year[['pow', 'year', 'funding_cum']], 
                                            on=['pow', 'year'], how='left')
df_staggered_did['funding_cum'] = df_staggered_did['funding_cum'].fillna(0)

# %%
print("Staggered DiD treatment structure:")
display(df_staggered_did.head(10))

# Summary: which powiats treated when?
display(df_treatment_timing.sort_values('treatment_year').head(10))
# Out:
# Staggered DiD treatment structure:
#               pow  year  treated  time_to_treatment   funding_cum
# 0  Biała Podlaska  2014        1                0.0  2.646463e+07
# 1  Biała Podlaska  2015        1                1.0  3.447804e+07
# 2  Biała Podlaska  2016        1                2.0  1.091886e+08
# 3  Biała Podlaska  2017        1                3.0  1.469402e+08
# 4  Biała Podlaska  2018        1                4.0  2.116581e+08
# 5  Biała Podlaska  2019        1                5.0  2.339718e+08
# 6  Biała Podlaska  2020        1                6.0  2.987195e+08
# 7  Biała Podlaska  2021        1                7.0  3.161128e+08
# 8  Biała Podlaska  2022        1                8.0  3.198439e+08
# 9  Biała Podlaska  2023        1                9.0  3.219366e+08
#                               pow  treatment_year  total_funding  num_projects
# 394                    żuromiński            2014   1.730454e+08           154
# 369                          Łódź            2014   7.612179e+09          2551
# 370                         łaski            2014   1.905702e+08           202
# 371                      łańcucki            2014   4.494919e+08           260
# 372                       łobeski            2014   2.266230e+08           134
# 373                     łomżyński            2014   4.534121e+08           330
# 27   Klaipedos rajono savivaldybe            2014   2.267455e+06            23
# 375                       łowicki            2014   3.934279e+08           301
# 376                      łukowski            2014   5.533870e+08           516
# 377               łódzki wschodni            2014   4.552300e+08           534

# %%
df_treatment_timing.treatment_year.value_counts().sort_index()
# Out:
# treatment_year
# 2014    360
# 2015     27
# 2016      8
# 2017      2
# 2022      1
# Name: count, dtype: int64

# %%
# Save
df_staggered_did.to_parquet(r"data\outputs\eu_flows\pol_1420_treatment_staggered_did.parquet", index=False)
df_treatment_timing.to_parquet(r"data\outputs\eu_flows\pol_1420_treatment_timing.parquet", index=False)

# %% [markdown]
# ### Programme period 2021-2027

# %%
PL_projects_21_27 = pd.read_excel(r"data\inputs\dane_gus\lista_projektow_UE_2021_27\Lista_projektow_FE_2021_2027_02112025.xlsx", header = 1)

# %% [markdown]
# #### Clean up

# %%
from src.functions import *

# %%
PL_projects_21_27.drop(columns=[
    "Działanie/ Measure",
    # "Cel szczegółowy/ Specific objective",
    "Priorytet/ Priority", 
    "Działanie/ Measure",
    "Numer identyfikacyjny statku w rejestrze floty rybackiej UE/ The Union fishing fleet register identification number",
    "Nazwa wykonawcy kontraktu/ The contractor’s name",
    "Kategoria wsparcia/ Type of intervention"
], inplace=True)

PL_projects_21_27 = clean_english_colnames(PL_projects_21_27, normalize='keep')   
PL_projects_21_27 = PL_projects_21_27[PL_projects_21_27['Fund'] != 'BAR']

# %%
PL_projects_21_27["EU co-financing (EUR)"] = PL_projects_21_27["EU co-financing (PLN)"]/4.4975 # this exchange rate was taken from the report

# %%
# PL_projects_21_27.head()

# %%
PL_projects_21_27.columns
# Out:
# Index(['Project name', 'Project summary', 'Contract number',
#        'Beneficiary name', 'Fund', 'Specific objective', 'Programme',
#        'Total project value (PLN)', 'Union co-financing rate (%)',
#        'EU co-financing (PLN)', 'EURO exchange rate', 'Project location',
#        'Project start date', 'Project end date', 'EU co-financing (EUR)'],
#       dtype='object')

# %%
df_locations = unnest_locations_with_gmina(PL_projects_21_27, 'Project location', 'EU co-financing (PLN)','EU co-financing (EUR)')

print(f"Original rows: {len(PL_projects_21_27)}")
print(f"Rows after unnesting: {len(df_locations)}")
# Out:
# Original rows: 23826
# Rows after unnesting: 50011

# %%
# save output
df_locations.to_csv(r"data\outputs\eu_flows\pol_21_27_projects_by_location.csv", index=False)

# %%
df_locations = add_iso3_column(df_locations)
# df_locations = df_locations[df_locations['iso3'] == 'POL']

# %%
# df_locations["pow"].unique()

# %%
df_locations.head(3)
# Out:
#                                         Project name  \
# 0  Poprawa warunków recepcyjnych dla osób ubiegaj...
# 1  Poprawa warunków recepcyjnych dla osób ubiegaj...
# 2  Bezpieczna Przystań - Centrum Pomocy Kobietom ...
#
#                                      Project summary  \
# 0  Polski system recepcyjny musi być przygotowany...
# 1  Polski system recepcyjny musi być przygotowany...
# 2  Szef Urzędu do Spraw Cudzoziemców (UdSC) jest ...
#
#             Contract number                   Beneficiary name  Fund  \
# 0  FAMI.01.01-IZ.00-0001/24  Szef Urzędu do Spraw Cudzoziemców  FAMI
# 1  FAMI.01.01-IZ.00-0001/24  Szef Urzędu do Spraw Cudzoziemców  FAMI
# 2  FAMI.01.01-IZ.00-0001/25  Szef Urzędu do Spraw Cudzoziemców  FAMI
#
#                                   Specific objective  \
# 0  FAMI.1 Wzmacnianie i rozwijanie wszystkich asp...
# 1  FAMI.1 Wzmacnianie i rozwijanie wszystkich asp...
# 2  FAMI.1 Wzmacnianie i rozwijanie wszystkich asp...
#
#                               Programme  Total project value (PLN)  \
# 0  Fundusz Azylu, Migracji i Integracji                41273504.53
# 1  Fundusz Azylu, Migracji i Integracji                41273504.53
# 2  Fundusz Azylu, Migracji i Integracji                67327046.73
#
#    Union co-financing rate (%)  EU co-financing (PLN)  EURO exchange rate  \
# 0                         80.0            33018803.62                 NaN
# 1                         80.0            33018803.62                 NaN
# 2                         75.0            50495285.04                 NaN
#
#                                     Project location  Project start date  \
# 0  WOJ: LUBELSKIE, POW: Biała Podlaska, GM: Biała... 2024-10-01 23:59:59
# 1       WOJ: PODLASKIE, POW: zambrowski, GM: Zambrów 2024-10-01 23:59:59
# 2     WOJ: MAZOWIECKIE, POW: legionowski, GM: Serock 2025-05-01 23:59:59
#
#      Project end date  EU co-financing (EUR)          woj             pow  \
# 0 2028-12-31 23:59:59           7.341591e+06    LUBELSKIE  Biała Podlaska
# 1 2028-12-31 23:59:59           7.341591e+06    PODLASKIE      zambrowski
# 2 2029-12-31 23:59:59           1.122741e+07  MAZOWIECKIE     legionowski
#
#             gmina  funding_split iso3
# 0  Biała Podlaska    16509401.81  POL
# 1         Zambrów    16509401.81  POL
# 2          Serock    50495285.04  POL

# %% [markdown]
# #### Reshape df so that powiats are row indexes
#
# panel structure with treatment timing

# %%
# Convert dates to datetime
df_locations['Project start date'] = pd.to_datetime(df_locations['Project start date'], errors='coerce')
df_locations['Project end date'] = pd.to_datetime(df_locations['Project end date'], errors='coerce')

# Extract year of first project (treatment year)
df_locations['year_start'] = df_locations['Project start date'].dt.year

# --- Powiat-level treatment timing (kept for reference) ---
df_treatment_timing = df_locations.groupby('pow').agg({
    'year_start': 'min',    # first year treated
    'funding_split': 'sum',
    'Contract number': 'nunique'
}).reset_index()
df_treatment_timing.columns = ['pow', 'treatment_year', 'total_funding', 'num_projects']

# --- Gmina-level treatment timing ---
# Group by pow + gmina (gmina may be None for some rows)
df_treatment_timing_gmina = df_locations.groupby(['pow', 'gmina']).agg({
    'year_start': 'min',
    'funding_split': 'sum',
    'Contract number': 'nunique'
}).reset_index()
df_treatment_timing_gmina.columns = ['pow', 'gmina', 'treatment_year', 'total_funding', 'num_projects']

# Create binary treatment indicator for each year at gmina level
years = range(int(df_locations['year_start'].min()), int(df_locations['year_start'].max()) + 1)
treatment_data = []
for _, row in df_treatment_timing_gmina.iterrows():
    pow_ = row['pow']
    gmina_ = row['gmina']
    treat_year = int(row['treatment_year']) if pd.notna(row['treatment_year']) else None
    for year in years:
        treated = 1 if (treat_year is not None and year >= treat_year) else 0
        ttt = (year - treat_year) if (treat_year is not None and year >= treat_year) else None
        treatment_data.append({
            'pow': pow_,
            'gmina': gmina_,
            'year': year,
            'treated': treated,
            'time_to_treatment': ttt
        })

df_staggered_did_gmina = pd.DataFrame(treatment_data)

# Add cumulative funding received by that year at gmina level (intensity)
df_funding_by_year_gmina = df_locations.groupby(['pow', 'gmina', 'year_start'])['funding_split'].sum().reset_index()
df_funding_by_year_gmina.columns = ['pow', 'gmina', 'year', 'funding_that_year']
df_funding_by_year_gmina['funding_cum'] = df_funding_by_year_gmina.groupby(['pow', 'gmina'])['funding_that_year'].cumsum()

df_staggered_did_gmina = df_staggered_did_gmina.merge(
    df_funding_by_year_gmina[['pow', 'gmina', 'year', 'funding_cum']],
    on=['pow', 'gmina', 'year'],
    how='left'
)
df_staggered_did_gmina['funding_cum'] = df_staggered_did_gmina['funding_cum'].fillna(0)

# Quick checks / outputs
print("Gmina-level staggered DiD (first rows):")
display(df_staggered_did_gmina.head(10))

print("Powiat-level treatment timing (sample):")
display(df_treatment_timing.sort_values('treatment_year').head(10))
# Out:
# Gmina-level staggered DiD (first rows):
#               pow           gmina  year  treated  time_to_treatment  \
# 0  Biała Podlaska  Biała Podlaska  2014        0                NaN
# 1  Biała Podlaska  Biała Podlaska  2015        0                NaN
# 2  Biała Podlaska  Biała Podlaska  2016        0                NaN
# 3  Biała Podlaska  Biała Podlaska  2017        0                NaN
# 4  Biała Podlaska  Biała Podlaska  2018        0                NaN
# 5  Biała Podlaska  Biała Podlaska  2019        0                NaN
# 6  Biała Podlaska  Biała Podlaska  2020        0                NaN
# 7  Biała Podlaska  Biała Podlaska  2021        1                0.0
# 8  Biała Podlaska  Biała Podlaska  2022        1                1.0
# 9  Biała Podlaska  Biała Podlaska  2023        1                2.0
#
#     funding_cum
# 0  0.000000e+00
# 1  0.000000e+00
# 2  0.000000e+00
# 3  0.000000e+00
# 4  0.000000e+00
# 5  0.000000e+00
# 6  0.000000e+00
# 7  1.422843e+08
# 8  1.840325e+08
# 9  2.169065e+08
# Powiat-level treatment timing (sample):
#                pow  treatment_year  total_funding  num_projects
# 395      łomżyński            2014   3.480943e+08            44
# 41          Kraków            2014   3.375614e+09           370
# 283      poznański            2014   8.165890e+08           163
# 374      węgrowski            2014   1.057504e+08            72
# 270    oświęcimski            2014   6.102660e+08           152
# 380  zawierciański            2014   2.923150e+08           155
# 235         miński            2014   1.447209e+08           100
# 197      krakowski            2014   8.129038e+08           198
# 313      siedlecki            2014   9.663685e+08           102
# 366     wrocławski            2014   4.198985e+08            93

# %%
# Save outputs
df_staggered_did_gmina.to_parquet(r"data\outputs\eu_flows\pol_2127_treatment_staggered_did_gmina.parquet", index=False)
df_treatment_timing_gmina.to_parquet(r"data\outputs\eu_flows\pol_2127_treatment_timing_gmina.parquet", index=False)
df_treatment_timing.to_parquet(r"data\outputs\eu_flows\pol_2127_treatment_timing_pow.parquet", index=False)

# %%
display(df_locations[['Contract number','Project location', 'woj', 'pow', 'funding_split']].head(10))
# display(df_locations.head(3))
# Out:
#              Contract number  \
# 0   FAMI.01.01-IZ.00-0001/24
# 1   FAMI.01.01-IZ.00-0001/24
# 2   FAMI.01.01-IZ.00-0001/25
# 6   FAMI.02.01-IZ.00-0001/25
# 12  FAMI.02.01-IZ.00-0007/24
# 18  FAMI.02.01-IZ.00-0013/24
# 29  FAMI.02.01-IZ.00-0025/24
# 30  FAMI.02.01-IZ.00-0025/24
# 31  FAMI.02.01-IZ.00-0025/24
# 32  FAMI.02.01-IZ.00-0025/24
#
#                                      Project location           woj  \
# 0   WOJ: LUBELSKIE, POW: Biała Podlaska, GM: Biała...     LUBELSKIE
# 1        WOJ: PODLASKIE, POW: zambrowski, GM: Zambrów     PODLASKIE
# 2      WOJ: MAZOWIECKIE, POW: legionowski, GM: Serock   MAZOWIECKIE
# 6                  WOJ: MAŁOPOLSKIE, POW: nowosądecki   MAŁOPOLSKIE
# 12      WOJ: PODLASKIE, POW: Białystok, GM: Białystok     PODLASKIE
# 18      WOJ: MAZOWIECKIE, POW: Warszawa, GM: Warszawa   MAZOWIECKIE
# 29  WOJ: DOLNOŚLĄSKIE, POW: Jelenia Góra, GM: Jele...  DOLNOŚLĄSKIE
# 30       WOJ: DOLNOŚLĄSKIE, POW: Legnica, GM: Legnica  DOLNOŚLĄSKIE
# 31   WOJ: DOLNOŚLĄSKIE, POW: Wałbrzych, GM: Wałbrzych  DOLNOŚLĄSKIE
# 32       WOJ: DOLNOŚLĄSKIE, POW: Wrocław, GM: Wrocław  DOLNOŚLĄSKIE
#
#                pow  funding_split
# 0   Biała Podlaska   1.650940e+07
# 1       zambrowski   1.650940e+07
# 2      legionowski   5.049529e+07
# 6      nowosądecki   9.000000e+05
# 12       Białystok   3.388984e+06
# 18        Warszawa   2.708900e+07
# 29    Jelenia Góra   9.755579e+06
# 30         Legnica   9.755579e+06
# 31       Wałbrzych   9.755579e+06
# 32         Wrocław   9.755579e+06

# %%
df_staggered_did_gmina
# Out:
#                  pow         gmina  year  treated  time_to_treatment  \
# 0            Bautzen       Przewóz  2014        0                NaN
# 1            Bautzen       Przewóz  2015        0                NaN
# 2            Bautzen       Przewóz  2016        0                NaN
# 3            Bautzen       Przewóz  2017        0                NaN
# 4            Bautzen       Przewóz  2018        0                NaN
# ...              ...           ...   ...      ...                ...
# 36171  Žilinský kraj  Zebrzydowice  2023        1                0.0
# 36172  Žilinský kraj  Zebrzydowice  2024        1                1.0
# 36173  Žilinský kraj  Zebrzydowice  2025        1                2.0
# 36174  Žilinský kraj  Zebrzydowice  2026        1                3.0
# 36175  Žilinský kraj  Zebrzydowice  2027        1                4.0
#
#        funding_cum
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
# ...            ...
# 36171   1802074.13
# 36172         0.00
# 36173         0.00
# 36174         0.00
# 36175         0.00
#
# [36176 rows x 6 columns]

# %% [markdown]
# #### Comine into 1 dataset

# %%
df_1420 = pd.read_parquet(r"data\outputs\eu_flows\pol_1420_treatment_staggered_did.parquet")
df_2127 = pd.read_parquet(r"data\outputs\eu_flows\pol_2127_treatment_staggered_did_gmina.parquet")

# 1420 doesn't have gmina, add it as None
if 'gmina' not in df_1420.columns:
    df_1420['gmina'] = None

# Stack the datasets
df_combined = pd.concat([df_1420, df_2127], axis=0, ignore_index=True)

# Sort and ensure panel structure
df_combined = df_combined.sort_values(['pow', 'gmina', 'year']).reset_index(drop=True)

# Create period identifier
df_combined['programme'] = df_combined['year'].apply(lambda x: '2014-2020' if x <= 2020 else '2021-2027')

# Handle treatment timing across periods
df_combined['ever_treated'] = df_combined.groupby(['pow', 'gmina'])['treated'].transform('max')

# Create lead/lag variables using transform (returns aligned Series)
def years_since_treat(x):
    if (x['treated'] == 1).any():
        first_treat_year = x.loc[x['treated'] == 1, 'year'].min()
        return x['year'] - first_treat_year
    else:
        return np.nan

df_combined['years_since_treatment'] = df_combined.groupby(['pow', 'gmina'], group_keys=False).apply(years_since_treat, include_groups=False)

print("Combined dataset shape:", df_combined.shape)
print("Year range:", df_combined['year'].min(), "to", df_combined['year'].max())
print("Treated units:", df_combined['ever_treated'].sum())
display(df_combined.head(15))
# Out:
# Combined dataset shape: (36614, 9)
# Year range: 2014 to 2027
# Treated units: 32634.0
#                pow  year  treated  time_to_treatment   funding_cum  \
# 0   Biała Podlaska  2014        0                NaN  0.000000e+00
# 1   Biała Podlaska  2015        0                NaN  0.000000e+00
# 2   Biała Podlaska  2016        0                NaN  0.000000e+00
# 3   Biała Podlaska  2017        0                NaN  0.000000e+00
# 4   Biała Podlaska  2018        0                NaN  0.000000e+00
# 5   Biała Podlaska  2019        0                NaN  0.000000e+00
# 6   Biała Podlaska  2020        0                NaN  0.000000e+00
# 7   Biała Podlaska  2021        1                0.0  1.422843e+08
# 8   Biała Podlaska  2022        1                1.0  1.840325e+08
# 9   Biała Podlaska  2023        1                2.0  2.169065e+08
# 10  Biała Podlaska  2024        1                3.0  2.509193e+08
# 11  Biała Podlaska  2025        1                4.0  2.629092e+08
# 12  Biała Podlaska  2026        1                5.0  2.694785e+08
# 13  Biała Podlaska  2027        1                6.0  0.000000e+00
# 14  Biała Podlaska  2014        1                0.0  2.646463e+07
#
#              gmina  programme  ever_treated  years_since_treatment
# 0   Biała Podlaska  2014-2020           1.0                   -7.0
# 1   Biała Podlaska  2014-2020           1.0                   -6.0
# 2   Biała Podlaska  2014-2020           1.0                   -5.0
# 3   Biała Podlaska  2014-2020           1.0                   -4.0
# 4   Biała Podlaska  2014-2020           1.0                   -3.0
# 5   Biała Podlaska  2014-2020           1.0                   -2.0
# 6   Biała Podlaska  2014-2020           1.0                   -1.0
# 7   Biała Podlaska  2021-2027           1.0                    0.0
# 8   Biała Podlaska  2021-2027           1.0                    1.0
# 9   Biała Podlaska  2021-2027           1.0                    2.0
# 10  Biała Podlaska  2021-2027           1.0                    3.0
# 11  Biała Podlaska  2021-2027           1.0                    4.0
# 12  Biała Podlaska  2021-2027           1.0                    5.0
# 13  Biała Podlaska  2021-2027           1.0                    6.0
# 14            None  2014-2020           NaN                    NaN

# %%
df_combined.ever_treated.unique()
# Out:
# array([ 1., nan])

# %%
# Save combined dataset
df_combined.to_parquet(r"data\clean\eu_flows\pol_combined_1420_2127_panel.parquet", index=False)

# %% [markdown]
# ## EU Cohesion funding

# %%
keys_path = os.path.join(os.getcwd(), "keys", "api_keys.ipy")
keys = runpy.run_path(keys_path)   
kohesio_key = keys.get("kohesio_key")

# %%
url = "https://keep.eu/api/open-data"
params = {"key": kohesio_key}

# %%
# Load the JSON file
with open(r"data\inputs\cohesion_data_europa\keep.eu_opendata_202511291224.json", "r", encoding='utf-8') as f:
    data = json.load(f)

programmes = data.get("programmes", [])
df_programmes = pd.json_normalize(programmes)

# %%
# print(df_programmes)

# %%
projects_list = []
for idx, row in df_programmes.iterrows():
    if isinstance(row['projects'], list):
        for project in row['projects']:
            project_dict = project.copy() if isinstance(project, dict) else {}
            project_dict['programme_id'] = row['id']
            project_dict['programme_title'] = row['title']
            project_dict['programme_period'] = row['period']
            project_dict['eu_funding'] = row['eu_funding']
            projects_list.append(project_dict)

df_projects = pd.DataFrame(projects_list)
print(f"Total projects extracted: {len(df_projects)}")
print(df_projects.head())

# %%
# After creating df_projects, flatten nested columns
df_projects_flat = df_projects.copy()

# Convert dict/list columns to JSON strings for CSV storage
for col in df_projects_flat.columns:
    if df_projects_flat[col].dtype == 'object':
        # Check if column contains dicts or lists
        if df_projects_flat[col].apply(lambda x: isinstance(x, (dict, list))).any():
            df_projects_flat[col] = df_projects_flat[col].apply(
                lambda x: json.dumps(x) if isinstance(x, (dict, list)) else x
            )

# %%
kohesio = pd.read_csv(r"data\outputs\cohesion_projects_all.csv")
# Out:
# C:\Users\jarem\AppData\Local\Temp\ipykernel_17440\414517678.py:1: DtypeWarning: Columns (1,4,7,8,9,10,11,13,14,15,20,45,49,50,51,52,53,61,62,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   kohesio = pd.read_csv(r"data\outputs\cohesion_projects_all.csv")

# %%
kohesio.tail()
# Out:
#          acronym project_id  \
# 30998  UrbanCOOP        NaN
# 30999    VIADUCT        NaN
# 31000  WEEEWaste        NaN
# 31001   WeSTEMEU        NaN
# 31002        ZCI        NaN
#
#                                             translations  \
# 30998  {'en': {'name': 'Better cooperation governance...
# 30999  {'en': {'name': 'Valorising public research to...
# 31000  {'en': {'name': 'Improving policies for waste ...
# 31001  {'en': {'name': 'Women for Science, Technology...
# 31002  {'en': {'name': 'Zero Carbon Infrastructure', ...
#
#                                                   themes call documents  \
# 30998   ['Urban development', 'Governance, partnership']  NaN        []
# 30999  ['Clustering and economic cooperation', 'Knowl...  NaN        []
# 31000  ['Regional planning and development', 'Waste a...  NaN        []
# 31001  ['Regional planning and development', 'Social ...  NaN        []
# 31002  ['Regional planning and development', 'Climate...  NaN        []
#
#         status relevant_mentions_and_prizes relevant_precedent_projects  \
# 30998  ongoing                          NaN                         NaN
# 30999  ongoing                          NaN                         NaN
# 31000  ongoing                          NaN                         NaN
# 31001  ongoing                          NaN                         NaN
# 31002  ongoing                          NaN                         NaN
#
#       relevant_subsequent_projects  ... eusalp  \
# 30998                          NaN  ...  False
# 30999                          NaN  ...  False
# 31000                          NaN  ...  False
# 31001                          NaN  ...  False
# 31002                          NaN  ...  False
#
#       eusalp_p_area_horizontal_action eusalp_degree_of_compliance hierarchy  \
# 30998                             NaN                         NaN       NaN
# 30999                             NaN                         NaN       NaN
# 31000                             NaN                         NaN       NaN
# 31001                             NaN                         NaN       NaN
# 31002                             NaN                         NaN       NaN
#
#       number_of_partnerships  \
# 30998                      1
# 30999                      1
# 31000                      1
# 31001                      1
# 31002                      1
#
#                                             partnerships programme_id  \
# 30998  [{'partner_name': '', 'partner_translated_name...          394
# 30999  [{'partner_name': '', 'partner_translated_name...          394
# 31000  [{'partner_name': 'České vysoké učení technick...          394
# 31001  [{'partner_name': '', 'partner_translated_name...          394
# 31002  [{'partner_name': '', 'partner_translated_name...          394
#
#                                  programme_title programme_period  \
# 30998  2021 - 2027 Interreg VI-C Interreg Europe        2021-2027
# 30999  2021 - 2027 Interreg VI-C Interreg Europe        2021-2027
# 31000  2021 - 2027 Interreg VI-C Interreg Europe        2021-2027
# 31001  2021 - 2027 Interreg VI-C Interreg Europe        2021-2027
# 31002  2021 - 2027 Interreg VI-C Interreg Europe        2021-2027
#
#       programme_type
# 30998  Interregional
# 30999  Interregional
# 31000  Interregional
# 31001  Interregional
# 31002  Interregional
#
# [5 rows x 73 columns]

# %%
NUTS2_funding = pd.read_csv(r"data\inputs\cohesion_data_europa\Historic_EU_payments_annual_timeseries_-_regionalised_and_modelled_20251126.csv")

# %%
NUTS2_funding
# Out:
#       Country NUTS1_ID                                    NUTS2 code+name  \
# 0          BE      BE1  BE10 Région de Bruxelles-Capitale / Brussels H...
# 1          BE      BE1  BE10 Région de Bruxelles-Capitale / Brussels H...
# 2          BE      BE1  BE10 Région de Bruxelles-Capitale / Brussels H...
# 3          BE      BE1  BE10 Région de Bruxelles-Capitale / Brussels H...
# 4          BE      BE1  BE10 Région de Bruxelles-Capitale / Brussels H...
# ...       ...      ...                                                ...
# 41335      UK      UKZ                            UKZZ Extra-Regio NUTS 2
# 41336      UK      UKZ                            UKZZ Extra-Regio NUTS 2
# 41337      UK      UKZ                            UKZZ Extra-Regio NUTS 2
# 41338      UK      UKZ                            UKZZ Extra-Regio NUTS 2
# 41339      UK      UKZ                            UKZZ Extra-Regio NUTS 2
#
#       NUTS2_ID                                         NUTS2_name   Fund  \
# 0         BE10  Région de Bruxelles-Capitale / Brussels Hoofds...  EAFRD
# 1         BE10  Région de Bruxelles-Capitale / Brussels Hoofds...  EAFRD
# 2         BE10  Région de Bruxelles-Capitale / Brussels Hoofds...  EAFRD
# 3         BE10  Région de Bruxelles-Capitale / Brussels Hoofds...  EAFRD
# 4         BE10  Région de Bruxelles-Capitale / Brussels Hoofds...  EAFRD
# ...        ...                                                ...    ...
# 41335     UKZZ                                 Extra-Regio NUTS 2    ESF
# 41336     UKZZ                                 Extra-Regio NUTS 2    ESF
# 41337     UKZZ                                 Extra-Regio NUTS 2    ESF
# 41338     UKZZ                                 Extra-Regio NUTS 2    ESF
# 41339     UKZZ                                 Extra-Regio NUTS 2    ESF
#
#        Year Programming_Period EU_Payment_annual Modelled_annual_expenditure  \
# 0      1993          1989-1993                 0                         211
# 1      1994          1989-1993               589                         508
# 2      1995          1989-1993               339                         256
# 3      1996          1989-1993                 0                         139
# 4      1997          1989-1993               521                         334
# ...     ...                ...               ...                         ...
# 41335  2018          2014-2020           281,494                     242,524
# 41336  2019          2014-2020           131,913                     924,167
# 41337  2020          2014-2020         3,172,883                   2,374,081
# 41338  2021          2014-2020            74,662                      96,915
# 41339  2022          2014-2020           192,194                     142,122
#
#       Standard_Deviation_of_annual_expenditure  \
# 0                                           24
# 1                                           15
# 2                                           29
# 3                                           38
# 4                                           21
# ...                                        ...
# 41335                                    6,724
# 41336                                  136,700
# 41337                                  138,053
# 41338                                    9,286
# 41339                                    8,639
#
#       Standard_Error_of_modelled_annual_expenditure
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 1
# 4                                                 0
# ...                                             ...
# 41335                                           212
# 41336                                         4,322
# 41337                                         4,365
# 41338                                           293
# 41339                                           273
#
# [41340 rows x 12 columns]

# %% [markdown]
# ## Elections data

# %%
df = pd.read_csv(r"data\inputs\election_data\Populists_dataset\The PopuList 3.0.csv", delimiter=';')

# %%
df
# Out:
#                             party_name    country_name  \
# 0           Bündnis Zukunft Österreich         Austria
# 1     Freiheitliche Partei Österreichs         Austria
# 2              Liste Hans-Peter Martin         Austria
# 3                        Team Stronach         Austria
# 4                   JETZT - Liste Pilz         Austria
# ..                                 ...             ...
# 229                        solidaritéS     Switzerland
# 230          Democratic Unionist Party  United Kingdom
# 231      Respect – The Unity Coalition  United Kingdom
# 232  United Kingdom Independence Party  United Kingdom
# 233              Brexit Party / Reform  United Kingdom
#
#                      party_name_english party_name_short  populist  \
# 0    Alliance for the Future of Austria              BZÖ         1
# 1              Freedom Party of Austria              FPÖ         1
# 2              Hans-Peter Martin's List           Martin         1
# 3                         Team Stronach               TS         1
# 4                       NOW – Pilz List             Pilz         1
# ..                                  ...              ...       ...
# 229                          Solidarity              SOL         0
# 230           Democratic Unionist Party              DUP         1
# 231      Respect -- The Unity Coalition                R         1
# 232   United Kingdom Independence Party             UKIP         1
# 233               Brexit Party / Reform     BRX / Reform         1
#
#      populist_start  populist_end  populist_startnobl  populist_endnobl  \
# 0              1900          2100                1900              2100
# 1              1900          2100                1900              2100
# 2              1900          2100                1900              2100
# 3              1900          2100                1900              2100
# 4              1900          2100                2100              2100
# ..              ...           ...                 ...               ...
# 229            2100          2100                2100              2100
# 230            1900          2100                2100              2100
# 231            1900          2100                1900              2100
# 232            1900          2100                1900              2100
# 233            1900          2100                1900              2100
#
#      populist_bl  ...  farleft_bl  eurosceptic  eurosceptic_start  \
# 0              0  ...           0            1               1900
# 1              0  ...           0            1               1900
# 2              0  ...           0            1               1900
# 3              0  ...           0            1               1900
# 4              1  ...           0            0               2100
# ..           ...  ...         ...          ...                ...
# 229            0  ...           0            1               1900
# 230            1  ...           0            1               1900
# 231            0  ...           0            1               1900
# 232            0  ...           0            1               1900
# 233            0  ...           0            1               1900
#
#      eurosceptic_end  eurosceptic_startnobl  eurosceptic_endnobl  \
# 0               2100                   1900                 2100
# 1               2100                   1900                 2100
# 2               2100                   1900                 2100
# 3               2100                   1900                 2100
# 4               2100                   2100                 2100
# ..               ...                    ...                  ...
# 229             2100                   1900                 2100
# 230             2100                   1900                 2100
# 231             2100                   1900                 2100
# 232             2100                   1900                 2100
# 233             2100                   1900                 2100
#
#      eurosceptic_bl  in_parliament  partyfacts_id  parlgov_id
# 0                 0            0.0          599.0      1536.0
# 1                 0            1.0          463.0        50.0
# 2                 0            0.0         1708.0       669.0
# 3                 0            0.0         1971.0      2150.0
# 4                 0            0.0         6137.0      2651.0
# ..              ...            ...            ...         ...
# 229               0            1.0         2939.0      1226.0
# 230               0            1.0          335.0       319.0
# 231               0            0.0         1082.0      1057.0
# 232               0            0.0          601.0      1272.0
# 233               0            0.0         7364.0      2729.0
#
# [234 rows x 31 columns]

# %%
df[df["country_name"] == "Poland"].party_name.unique()
# Out:
# array(['Konfederacja Odnowy Rzeczypospolitej Wolnosc i Nadzieja',
#        "Kukiz'15", 'Lewica Razem', 'Liga Polskich Rodzin', 'Partia X',
#        'Polski Zwiazek Zachodni', 'Prawo i Sprawiedliwosc',
#        'Ruch Narodowy', 'Ruch Odbudowy Polski',
#        'Samoobrona Rzeczypospolitej Polskiej', 'Unia Polityki Realnej ',
#        'Zjednoczenie Chrzescijansko-Narodowe',
#        'Konfederacja Wolność i Niepodległość',
#        'Konfederacja Korony Polskiej', 'Solidarna Polska',
#        'Kongres Nowej Prawicy'], dtype=object)

# %%
elections_df = pd.read_csv(r"data\inputs\election_data\Poland\gminy\wyniki_gl_na_listy_po_gminach_proc_sejm_csv\wyniki_gl_na_listy_po_gminach_proc_sejm_utf8.csv", delimiter=';')

# %%
elections_df = elections
# Out:
#       TERYT Gminy          Gmina       Powiat         Województwo  Nr okręgu  \
# 0             NaN        Albania    zagranica                 NaN         19
# 1             NaN       Algieria    zagranica                 NaN         19
# 2             NaN         Angola    zagranica                 NaN         19
# 3             NaN    Azerbejdżan    zagranica                 NaN         19
# 4             NaN      Argentyna    zagranica                 NaN         19
# ...           ...            ...          ...                 ...        ...
# 2580     321804.0      gm. Resko      łobeski  zachodniopomorskie         41
# 2581     321805.0  gm. Węgorzyno      łobeski  zachodniopomorskie         41
# 2582     326101.0       Koszalin     Koszalin  zachodniopomorskie         40
# 2583     326201.0       Szczecin     Szczecin  zachodniopomorskie         41
# 2584     326301.0    Świnoujście  Świnoujście  zachodniopomorskie         41
#
#       Liczba komisji  Liczba uwzględnionych komisji Frekwencja  \
# 0                  1                              1      95,32
# 1                  1                              1      90,91
# 2                  1                              1      88,89
# 3                  1                              1     100,00
# 4                  1                              1      88,84
# ...              ...                            ...        ...
# 2580               8                              8      60,72
# 2581               6                              6      61,49
# 2582              55                             55      75,99
# 2583             208                            208      77,88
# 2584              27                             27      74,74
#
#      Procent głosów nieważnych  \
# 0                         0,49
# 1                         5,00
# 2                         0,00
# 3                         2,30
# 4                        10,55
# ...                        ...
# 2580                      3,64
# 2581                      4,45
# 2582                      1,35
# 2583                      1,05
# 2584                      1,20
#
#      W tym z powodu postawienia znaku „X” obok nazwiska dwóch lub większej liczby kandydatów z różnych list  \
# 0                                                 25,00
# 1                                                 33,33
# 2                                                   NaN
# 3                                                 50,00
# 4                                                 90,48
# ...                                                 ...
# 2580                                              65,04
# 2581                                              68,84
# 2582                                              61,43
# 2583                                              49,98
# 2584                                              58,66
#
#       ... KOMITET WYBORCZY NOWA LEWICA  \
# 0     ...                        17,63
# 1     ...                        10,53
# 2     ...                         8,33
# 3     ...                        12,94
# 4     ...                        25,84
# ...   ...                          ...
# 2580  ...                         7,50
# 2581  ...                         7,40
# 2582  ...                         8,79
# 2583  ...                         9,78
# 2584  ...                        15,16
#
#      KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ  \
# 0                                       8,51
# 1                                      15,79
# 2                                      16,67
# 3                                       3,53
# 4                                      20,22
# ...                                      ...
# 2580                                   36,11
# 2581                                   40,10
# 2582                                   25,40
# 2583                                   25,25
# 2584                                   25,74
#
#      KOMITET WYBORCZY KONFEDERACJA WOLNOŚĆ I NIEPODLEGŁOŚĆ  \
# 0                                                  7,52
# 1                                                  8,77
# 2                                                 16,67
# 3                                                  5,88
# 4                                                  6,74
# ...                                                 ...
# 2580                                               4,95
# 2581                                               6,39
# 2582                                               5,71
# 2583                                               5,89
# 2584                                               5,30
#
#      KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI  \
# 0                                                 46,61
# 1                                                 47,37
# 2                                                 37,50
# 3                                                 60,00
# 4                                                 32,58
# ...                                                 ...
# 2580                                              34,20
# 2581                                              27,64
# 2582                                              45,76
# 2583                                              44,23
# 2584                                              41,30
#
#      KOMITET WYBORCZY POLSKA JEST JEDNA  \
# 0                                  1,23
# 1                                  0,00
# 2                                  8,33
# 3                                  2,35
# 4                                  0,00
# ...                                 ...
# 2580                               0,89
# 2581                               0,51
# 2582                               0,98
# 2583                               1,12
# 2584                               1,17
#
#      KOMITET WYBORCZY WYBORCÓW RUCHU DOBROBYTU I POKOJU  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2580                                               0,68
# 2581                                               0,84
# 2582                                                NaN
# 2583                                               0,24
# 2584                                               0,33
#
#      KOMITET WYBORCZY NORMALNY KRAJ KOMITET WYBORCZY ANTYPARTIA  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 2580                            NaN                         NaN
# 2581                            NaN                         NaN
# 2582                            NaN                         NaN
# 2583                            NaN                         NaN
# 2584                            NaN                         NaN
#
#      KOMITET WYBORCZY RUCH NAPRAWY POLSKI  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 2580                                  NaN
# 2581                                  NaN
# 2582                                  NaN
# 2583                                  NaN
# 2584                                  NaN
#
#      KOMITET WYBORCZY WYBORCÓW MNIEJSZOŚĆ NIEMIECKA
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2580                                            NaN
# 2581                                            NaN
# 2582                                            NaN
# 2583                                            NaN
# 2584                                            NaN
#
# [2585 rows x 25 columns]
