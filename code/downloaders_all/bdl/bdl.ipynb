# %%
import pandas as pd
panel = pd.read_csv("bdl_output/bdl_gmina_panel.csv")

# Check if major cities have finance data
cities = panel[panel['unit_name'].isin(['Kraków', 'Warszawa', 'Wrocław'])]
print(cities[['unit_name', 'year', 'revenue_total', 'own_revenue_per_capita']].head(15))
