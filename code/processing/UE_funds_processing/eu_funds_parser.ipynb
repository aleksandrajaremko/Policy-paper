# %%
# In a notebook:
from eu_funds_pipeline import EUFundsPipeline

config = {
    'PATH_TERYT': r"your\path\teryt_klucz_powiaty_gminy_lata_1999_2025-1.xlsx",
    'PATH_200713_POKL': r"your\path\Umowy_wszystko_POKL_30_06_2018.xls",
    'PATH_200713_INNE': r"your\path\Umowy_wszystko_INNE_30_06_2018.xls",
    'PATH_201420': r"your\path\Lista_projektow_FE_2014_2020_04012026.xlsx",
    'PATH_202127': r"your\path\Lista_projektow_FE_2021_2027_01022026.xlsx",
    'OUTPUT_DIR': r"your\path\output",
    'PATH_POPULATION': None,  # add BDL population CSV later
}

pipeline = EUFundsPipeline(config)
master = pipeline.run_all()
